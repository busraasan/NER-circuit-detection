# %%
import torch
from transformer_lens import HookedTransformer
from torch.utils.data import DataLoader, Dataset
# Out:
# /home/basan/fmvalid/lib/python3.11/site-packages/transformers/utils/hub.py:111: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(

# %%
def collate(batch):
    pos_prompts, answers, prompts = zip(*batch)
    return {"pos_prompts": list(pos_prompts), "prompts": list(prompts), "answers": list(answers)}

# %%
gpt = HookedTransformer.from_pretrained("gemma-2b", center_unembed=True, center_writing_weights=True, fold_ln=True)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# WARNING:root:You are not using LayerNorm, so the writing weights can't be centered! Skipping
# Loaded pretrained model gemma-2b into HookedTransformer

# %%
import json
import torch
from torch.utils.data import Dataset, DataLoader

# === Few-shot template ===
FEWSHOT_TEMPLATE = """Sentence: Apple announced a new iPhone during its annual product launch event.,
POS tag: PRODUCT,
Answer: iPhone

Sentence: Barack Obama delivered a keynote speech at the conference.,
POS tag: PERSON,
Answer: Barack Obama

Sentence: Tesla invested over 2 billion dollars in a new gigafactory in Germany.,
POS tag: MONEY,
Answer: 2 billion dollars

Sentence: The concert will take place at 8 p.m. on Saturday.,
POS tag: TIME,
Answer: 8 p.m. on Saturday

Sentence: The Eiffel Tower is located in Paris.,
POS tag: LOCATION,
Answer: Paris

Sentence: The Olympic Games in Tokyo attracted thousands of visitors despite the pandemic.,
POS tag: EVENT, 
Answer: Olympic Games

Sentence: The recipe calls for 200 grams of sugar and 3 eggs.,
POS tag: NUMERICAL, 
Answer: 200 grams

Sentence: Google has opened a new research center in Zurich to focus on AI development.,
POS tag: ORGANIZATION, 
Answer: Google

Sentence: The American have a long history of culinary excellence.,
POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP, 
Answer: American

Sentence: The Islam religion has over a billion followers worldwide.,
POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP, 
Answer: Islam

Sentence: {sentence}
POS tag: {tag}
Answer:"""

# === Dataset ===
class NERDataset(Dataset):
    def __init__(self, json_path, template=FEWSHOT_TEMPLATE):
        with open(json_path, "r", encoding="utf-8") as f:
            self.data = json.load(f)
        self.template = template

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        row = self.data[idx]
        sentence = row["Sentence"]
        tag = row["POS tag"]
        answer = row["Answer"]
        prompt = self.template.format(sentence=sentence, tag=tag)
        # Include raw fields so we can write them out on success
        return {"prompt": prompt, "answer": str(answer), "sentence": sentence, "tag": tag}

# === collate ===
def collate(batch):
    prompts = [b["prompt"] for b in batch]
    answers = [b["answer"] for b in batch]
    sentences = [b["sentence"] for b in batch]
    tags = [b["tag"] for b in batch]
    return {"prompts": prompts, "answers": answers, "sentences": sentences, "tags": tags}

# === evaluation ===
@torch.no_grad()
def next_token_accuracy(model, dataset, batch_size=16, print_info=True, save_path="/Users/merve/Desktop/last_code_path_patch/notebooks/dataset/ner_dataset_15each.json"):
    """
    Computes next-token accuracy. Additionally, if `save_path` is provided,
    writes a JSON file containing only CORRECT items in the format:
      [{"Sentence": ..., "POS tag": ..., "Answer": <prediction>}, ...]
    where Answer is the model's predicted *first token*.
    """
    device = getattr(model, "device", "cuda:1")
    model.to(device).eval()

    loader = DataLoader(dataset, batch_size=batch_size, shuffle=False, collate_fn=collate)

    total, correct = 0, 0
    correct_records = []

    def decode_token_ids(token_id):
        if hasattr(model, "tokenizer") and hasattr(model.tokenizer, "decode"):
            return model.tokenizer.decode([int(token_id)])
        # Fallback for HookedTransformer
        return model.to_string(torch.tensor([[int(token_id)]], device=device))

    for batch in loader:
        prompts, answers = batch["prompts"], batch["answers"]
        sentences, tags = batch["sentences"], batch["tags"]

        # tokenize each prompt
        prompt_tok_list = [model.to_tokens(p, prepend_bos=True) for p in prompts]
        prompt_lens = [t.size(1) for t in prompt_tok_list]
        pad_id = (
            model.tokenizer.pad_token_id
            if hasattr(model, "tokenizer") and hasattr(model.tokenizer, "pad_token_id") and model.tokenizer.pad_token_id is not None
            else (model.tokenizer.eot if hasattr(model, "tokenizer") and hasattr(model.tokenizer, "eot") else 0)
        )
        toks = torch.nn.utils.rnn.pad_sequence(
            [t.squeeze(0) for t in prompt_tok_list],
            batch_first=True,
            padding_value=pad_id
        ).to(device)

        # forward
        logits = model(toks)  # [B, T_max, V]
        last_idx = torch.tensor([L - 1 for L in prompt_lens], device=toks.device)  # [B]
        next_logits = logits.gather(1, last_idx.view(-1,1,1).expand(-1,1,logits.size(-1))).squeeze(1)  # [B, V]
        pred_ids = next_logits.argmax(dim=-1)  # [B]

        # gold ids
        gold_ids = []
        for p, a, L in zip(prompts, answers, prompt_lens):
            both = model.to_tokens(p + " " + a, prepend_bos=True)
            gold_ids.append(int(both[0, L].item()))
        gold_ids = torch.tensor(gold_ids, device=pred_ids.device)

        # decode for inspection
        pred_texts = [decode_token_ids(t).strip() for t in pred_ids.tolist()]
        gold_texts = [decode_token_ids(t).strip() for t in gold_ids.tolist()]

        # tally
        matches = (pred_ids == gold_ids)
        correct += matches.sum().item()
        total += pred_ids.numel()

        # collect correct items for JSON dump
        for i, is_ok in enumerate(matches.tolist()):
            if is_ok:
                # Write the *prediction* as the Answer
                correct_records.append({
                    "Sentence": sentences[i],
                    "POS tag": tags[i],
                    "Answer": pred_texts[i]  # predicted first token
                })

        if print_info:
            TOPK = 5
            topk_vals, topk_ids = next_logits.topk(TOPK, dim=-1)  # [B, K]
            topk_texts = [[decode_token_ids(token_id).strip() for token_id in row.tolist()] for row in topk_ids]
            print(len(prompts))
            for i in range(len(prompts)):
                print(i)
                print("—" * 48)
                print(f"Prompt: ", prompts[i])
                print(f"Gold answer: {answers[i]}")
                print(f"Gold first token: {gold_texts[i]!r}")
                print(f"Pred first token: {pred_texts[i]!r}")
                print(f"Top-{TOPK}: {topk_texts[i]}")

    acc = 0.0 if total == 0 else 100.0 * correct / total
    print(f"\n✅ Next-token accuracy: {correct}/{total} = {acc:.2f}%")

    torch.cuda.empty_cache()
    del toks, logits

    # Write JSON of correct predictions if requested
    # if save_path is not None:
    #     with open(save_path, "w", encoding="utf-8") as f:
    #         json.dump(correct_records, f, ensure_ascii=False, indent=2)
    #     print(f"💾 Wrote {len(correct_records)} correct items to {save_path}")

    return acc

# %%
JSON_PATH = "../../pos_cf_datasets/ner_dataset_15each.json"
ds = NERDataset(JSON_PATH)
next_token_accuracy(gpt, ds, batch_size=16)
# Out:
# Moving model to device:  cuda:1
# 16
# 0
# ————————————————————————————————————————————————
# Prompt:  Sentence: Apple announced a new iPhone during its annual product launch event.,
# POS tag: PRODUCT,
# Answer: iPhone
#
# Sentence: Barack Obama delivered a keynote speech at the conference.,
# POS tag: PERSON,
# Answer: Barack Obama
#
# Sentence: Tesla invested over 2 billion dollars in a new gigafactory in Germany.,
# POS tag: MONEY,
# Answer: 2 billion dollars
#
# Sentence: The concert will take place at 8 p.m. on Saturday.,
# POS tag: TIME,
# Answer: 8 p.m. on Saturday
#
# Sentence: The Eiffel Tower is located in Paris.,
# POS tag: LOCATION,
# Answer: Paris
#
# Sentence: The Olympic Games in Tokyo attracted thousands of visitors despite the pandemic.,
# POS tag: EVENT,
# Answer: Olympic Games
#
# Sentence: The recipe calls for 200 grams of sugar and 3 eggs.,
# POS tag: NUMERICAL,
# Answer: 200 grams
#
# Sentence: Google has opened a new research center in Zurich to focus on AI development.,
# POS tag: ORGANIZATION,
# Answer: Google
#
# Sentence: The American have a long history of culinary excellence.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: American
#
# Sentence: The Islam religion has over a billion followers worldwide.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: Islam
#
# Sentence: That is, the US public and scholars have, started to show concerns over the issue of right and wrong in WW II, the moral issue, that is, the US has started to pay attention to this issue.
# POS tag: EVENT
# Answer:
# Gold answer: WW II
# Gold first token: 'WW'
# Pred first token: 'The'
# Top-5: ['The', 'That', 'that', 'US', '']
# 1
# ————————————————————————————————————————————————
# Prompt:  Sentence: Apple announced a new iPhone during its annual product launch event.,
# POS tag: PRODUCT,
# Answer: iPhone
#
# Sentence: Barack Obama delivered a keynote speech at the conference.,
# POS tag: PERSON,
# Answer: Barack Obama
#
# Sentence: Tesla invested over 2 billion dollars in a new gigafactory in Germany.,
# POS tag: MONEY,
# Answer: 2 billion dollars
#
# Sentence: The concert will take place at 8 p.m. on Saturday.,
# POS tag: TIME,
# Answer: 8 p.m. on Saturday
#
# Sentence: The Eiffel Tower is located in Paris.,
# POS tag: LOCATION,
# Answer: Paris
#
# Sentence: The Olympic Games in Tokyo attracted thousands of visitors despite the pandemic.,
# POS tag: EVENT,
# Answer: Olympic Games
#
# Sentence: The recipe calls for 200 grams of sugar and 3 eggs.,
# POS tag: NUMERICAL,
# Answer: 200 grams
#
# Sentence: Google has opened a new research center in Zurich to focus on AI development.,
# POS tag: ORGANIZATION,
# Answer: Google
#
# Sentence: The American have a long history of culinary excellence.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: American
#
# Sentence: The Islam religion has over a billion followers worldwide.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: Islam
#
# Sentence: She always sets aside a little time for herself on New Year's Eve to do just this.
# POS tag: EVENT
# Answer:
# Gold answer: New Year's Eve
# Gold first token: 'New'
# Pred first token: 'New'
# Top-5: ['New', 'She', 'she', '', 'time']
# 2
# ————————————————————————————————————————————————
# Prompt:  Sentence: Apple announced a new iPhone during its annual product launch event.,
# POS tag: PRODUCT,
# Answer: iPhone
#
# Sentence: Barack Obama delivered a keynote speech at the conference.,
# POS tag: PERSON,
# Answer: Barack Obama
#
# Sentence: Tesla invested over 2 billion dollars in a new gigafactory in Germany.,
# POS tag: MONEY,
# Answer: 2 billion dollars
#
# Sentence: The concert will take place at 8 p.m. on Saturday.,
# POS tag: TIME,
# Answer: 8 p.m. on Saturday
#
# Sentence: The Eiffel Tower is located in Paris.,
# POS tag: LOCATION,
# Answer: Paris
#
# Sentence: The Olympic Games in Tokyo attracted thousands of visitors despite the pandemic.,
# POS tag: EVENT,
# Answer: Olympic Games
#
# Sentence: The recipe calls for 200 grams of sugar and 3 eggs.,
# POS tag: NUMERICAL,
# Answer: 200 grams
#
# Sentence: Google has opened a new research center in Zurich to focus on AI development.,
# POS tag: ORGANIZATION,
# Answer: Google
#
# Sentence: The American have a long history of culinary excellence.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: American
#
# Sentence: The Islam religion has over a billion followers worldwide.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: Islam
#
# Sentence: Well, as al - Jazeera TV station has been able to develop into its current status, what do you think has it relied upon so that its competitiveness and influential power, even surpassed CNN and BBC during the Iraq war ?
# POS tag: EVENT
# Answer:
# Gold answer: the Iraq war
# Gold first token: 'the'
# Pred first token: 'Al'
# Top-5: ['Al', 'As', '', 'CNN', '']
# 3
# ————————————————————————————————————————————————
# Prompt:  Sentence: Apple announced a new iPhone during its annual product launch event.,
# POS tag: PRODUCT,
# Answer: iPhone
#
# Sentence: Barack Obama delivered a keynote speech at the conference.,
# POS tag: PERSON,
# Answer: Barack Obama
#
# Sentence: Tesla invested over 2 billion dollars in a new gigafactory in Germany.,
# POS tag: MONEY,
# Answer: 2 billion dollars
#
# Sentence: The concert will take place at 8 p.m. on Saturday.,
# POS tag: TIME,
# Answer: 8 p.m. on Saturday
#
# Sentence: The Eiffel Tower is located in Paris.,
# POS tag: LOCATION,
# Answer: Paris
#
# Sentence: The Olympic Games in Tokyo attracted thousands of visitors despite the pandemic.,
# POS tag: EVENT,
# Answer: Olympic Games
#
# Sentence: The recipe calls for 200 grams of sugar and 3 eggs.,
# POS tag: NUMERICAL,
# Answer: 200 grams
#
# Sentence: Google has opened a new research center in Zurich to focus on AI development.,
# POS tag: ORGANIZATION,
# Answer: Google
#
# Sentence: The American have a long history of culinary excellence.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: American
#
# Sentence: The Islam religion has over a billion followers worldwide.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: Islam
#
# Sentence: Bi Li said that the goal of the Chinese Women's Football Team in the Asian Games would be to strive for champion but confirm second.
# POS tag: EVENT
# Answer:
# Gold answer: the Asian Games
# Gold first token: 'the'
# Pred first token: 'Asian'
# Top-5: ['Asian', '', 'The', 'Chinese', 'Goal']
# 4
# ————————————————————————————————————————————————
# Prompt:  Sentence: Apple announced a new iPhone during its annual product launch event.,
# POS tag: PRODUCT,
# Answer: iPhone
#
# Sentence: Barack Obama delivered a keynote speech at the conference.,
# POS tag: PERSON,
# Answer: Barack Obama
#
# Sentence: Tesla invested over 2 billion dollars in a new gigafactory in Germany.,
# POS tag: MONEY,
# Answer: 2 billion dollars
#
# Sentence: The concert will take place at 8 p.m. on Saturday.,
# POS tag: TIME,
# Answer: 8 p.m. on Saturday
#
# Sentence: The Eiffel Tower is located in Paris.,
# POS tag: LOCATION,
# Answer: Paris
#
# Sentence: The Olympic Games in Tokyo attracted thousands of visitors despite the pandemic.,
# POS tag: EVENT,
# Answer: Olympic Games
#
# Sentence: The recipe calls for 200 grams of sugar and 3 eggs.,
# POS tag: NUMERICAL,
# Answer: 200 grams
#
# Sentence: Google has opened a new research center in Zurich to focus on AI development.,
# POS tag: ORGANIZATION,
# Answer: Google
#
# Sentence: The American have a long history of culinary excellence.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: American
#
# Sentence: The Islam religion has over a billion followers worldwide.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: Islam
#
# Sentence: It is reported that after it received the scientific achievement award of Heilongjiang's Chinese Medicine Administrative Bureau in 1992, the Liver Healing Capsule also received a top award at the Malaysia International New Technology and New Product Exhibition, and in May of this year, it received the gold medal at the third National Medical and Health Care Products Fair.
# POS tag: EVENT
# Answer:
# Gold answer: the Malaysia International New Technology and New Product Exhibition
# Gold first token: 'the'
# Pred first token: ''
# Top-5: ['', 'It', 'The', 'Liver', 'In']
# 5
# ————————————————————————————————————————————————
# Prompt:  Sentence: Apple announced a new iPhone during its annual product launch event.,
# POS tag: PRODUCT,
# Answer: iPhone
#
# Sentence: Barack Obama delivered a keynote speech at the conference.,
# POS tag: PERSON,
# Answer: Barack Obama
#
# Sentence: Tesla invested over 2 billion dollars in a new gigafactory in Germany.,
# POS tag: MONEY,
# Answer: 2 billion dollars
#
# Sentence: The concert will take place at 8 p.m. on Saturday.,
# POS tag: TIME,
# Answer: 8 p.m. on Saturday
#
# Sentence: The Eiffel Tower is located in Paris.,
# POS tag: LOCATION,
# Answer: Paris
#
# Sentence: The Olympic Games in Tokyo attracted thousands of visitors despite the pandemic.,
# POS tag: EVENT,
# Answer: Olympic Games
#
# Sentence: The recipe calls for 200 grams of sugar and 3 eggs.,
# POS tag: NUMERICAL,
# Answer: 200 grams
#
# Sentence: Google has opened a new research center in Zurich to focus on AI development.,
# POS tag: ORGANIZATION,
# Answer: Google
#
# Sentence: The American have a long history of culinary excellence.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: American
#
# Sentence: The Islam religion has over a billion followers worldwide.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: Islam
#
# Sentence: According to its person in charge, the company planned to sell World Cup air during the present World Cup.
# POS tag: EVENT
# Answer:
# Gold answer: World Cup
# Gold first token: 'World'
# Pred first token: 'World'
# Top-5: ['World', '', 'According', 'The', 'the']
# 6
# ————————————————————————————————————————————————
# Prompt:  Sentence: Apple announced a new iPhone during its annual product launch event.,
# POS tag: PRODUCT,
# Answer: iPhone
#
# Sentence: Barack Obama delivered a keynote speech at the conference.,
# POS tag: PERSON,
# Answer: Barack Obama
#
# Sentence: Tesla invested over 2 billion dollars in a new gigafactory in Germany.,
# POS tag: MONEY,
# Answer: 2 billion dollars
#
# Sentence: The concert will take place at 8 p.m. on Saturday.,
# POS tag: TIME,
# Answer: 8 p.m. on Saturday
#
# Sentence: The Eiffel Tower is located in Paris.,
# POS tag: LOCATION,
# Answer: Paris
#
# Sentence: The Olympic Games in Tokyo attracted thousands of visitors despite the pandemic.,
# POS tag: EVENT,
# Answer: Olympic Games
#
# Sentence: The recipe calls for 200 grams of sugar and 3 eggs.,
# POS tag: NUMERICAL,
# Answer: 200 grams
#
# Sentence: Google has opened a new research center in Zurich to focus on AI development.,
# POS tag: ORGANIZATION,
# Answer: Google
#
# Sentence: The American have a long history of culinary excellence.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: American
#
# Sentence: The Islam religion has over a billion followers worldwide.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: Islam
#
# Sentence: The first Le Tian Cup China and Korea Go competition started today at Fushan, the second largest city of Korea.
# POS tag: EVENT
# Answer:
# Gold answer: Le Tian Cup China
# Gold first token: 'Le'
# Pred first token: 'Le'
# Top-5: ['Le', 'The', 'First', '', 'first']
# 7
# ————————————————————————————————————————————————
# Prompt:  Sentence: Apple announced a new iPhone during its annual product launch event.,
# POS tag: PRODUCT,
# Answer: iPhone
#
# Sentence: Barack Obama delivered a keynote speech at the conference.,
# POS tag: PERSON,
# Answer: Barack Obama
#
# Sentence: Tesla invested over 2 billion dollars in a new gigafactory in Germany.,
# POS tag: MONEY,
# Answer: 2 billion dollars
#
# Sentence: The concert will take place at 8 p.m. on Saturday.,
# POS tag: TIME,
# Answer: 8 p.m. on Saturday
#
# Sentence: The Eiffel Tower is located in Paris.,
# POS tag: LOCATION,
# Answer: Paris
#
# Sentence: The Olympic Games in Tokyo attracted thousands of visitors despite the pandemic.,
# POS tag: EVENT,
# Answer: Olympic Games
#
# Sentence: The recipe calls for 200 grams of sugar and 3 eggs.,
# POS tag: NUMERICAL,
# Answer: 200 grams
#
# Sentence: Google has opened a new research center in Zurich to focus on AI development.,
# POS tag: ORGANIZATION,
# Answer: Google
#
# Sentence: The American have a long history of culinary excellence.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: American
#
# Sentence: The Islam religion has over a billion followers worldwide.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: Islam
#
# Sentence: He said that Oliver North of Iran - Contra notoriety thought he had erased his computer but that the information was later retrieved for congressional committees to read.
# POS tag: EVENT
# Answer:
# Gold answer: Iran - Contra
# Gold first token: 'Iran'
# Pred first token: 'He'
# Top-5: ['He', 'Oliver', '', 'Congressional', 'Congress']
# 8
# ————————————————————————————————————————————————
# Prompt:  Sentence: Apple announced a new iPhone during its annual product launch event.,
# POS tag: PRODUCT,
# Answer: iPhone
#
# Sentence: Barack Obama delivered a keynote speech at the conference.,
# POS tag: PERSON,
# Answer: Barack Obama
#
# Sentence: Tesla invested over 2 billion dollars in a new gigafactory in Germany.,
# POS tag: MONEY,
# Answer: 2 billion dollars
#
# Sentence: The concert will take place at 8 p.m. on Saturday.,
# POS tag: TIME,
# Answer: 8 p.m. on Saturday
#
# Sentence: The Eiffel Tower is located in Paris.,
# POS tag: LOCATION,
# Answer: Paris
#
# Sentence: The Olympic Games in Tokyo attracted thousands of visitors despite the pandemic.,
# POS tag: EVENT,
# Answer: Olympic Games
#
# Sentence: The recipe calls for 200 grams of sugar and 3 eggs.,
# POS tag: NUMERICAL,
# Answer: 200 grams
#
# Sentence: Google has opened a new research center in Zurich to focus on AI development.,
# POS tag: ORGANIZATION,
# Answer: Google
#
# Sentence: The American have a long history of culinary excellence.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: American
#
# Sentence: The Islam religion has over a billion followers worldwide.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: Islam
#
# Sentence: He hopes that this issue would be resolved before the Christmas holiday.
# POS tag: EVENT
# Answer:
# Gold answer: Christmas
# Gold first token: 'Christmas'
# Pred first token: 'Christmas'
# Top-5: ['Christmas', 'This', '', 'issue', 'before']
# 9
# ————————————————————————————————————————————————
# Prompt:  Sentence: Apple announced a new iPhone during its annual product launch event.,
# POS tag: PRODUCT,
# Answer: iPhone
#
# Sentence: Barack Obama delivered a keynote speech at the conference.,
# POS tag: PERSON,
# Answer: Barack Obama
#
# Sentence: Tesla invested over 2 billion dollars in a new gigafactory in Germany.,
# POS tag: MONEY,
# Answer: 2 billion dollars
#
# Sentence: The concert will take place at 8 p.m. on Saturday.,
# POS tag: TIME,
# Answer: 8 p.m. on Saturday
#
# Sentence: The Eiffel Tower is located in Paris.,
# POS tag: LOCATION,
# Answer: Paris
#
# Sentence: The Olympic Games in Tokyo attracted thousands of visitors despite the pandemic.,
# POS tag: EVENT,
# Answer: Olympic Games
#
# Sentence: The recipe calls for 200 grams of sugar and 3 eggs.,
# POS tag: NUMERICAL,
# Answer: 200 grams
#
# Sentence: Google has opened a new research center in Zurich to focus on AI development.,
# POS tag: ORGANIZATION,
# Answer: Google
#
# Sentence: The American have a long history of culinary excellence.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: American
#
# Sentence: The Islam religion has over a billion followers worldwide.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: Islam
#
# Sentence: That is, the reason why it can establish itself is that it first relied on the Afghan war, and then the Iraq war after the 9 11.
# POS tag: EVENT
# Answer:
# Gold answer: the Afghan war
# Gold first token: 'the'
# Pred first token: 'The'
# Top-5: ['The', '', 'That', 'Afghanistan', 'that']
# 10
# ————————————————————————————————————————————————
# Prompt:  Sentence: Apple announced a new iPhone during its annual product launch event.,
# POS tag: PRODUCT,
# Answer: iPhone
#
# Sentence: Barack Obama delivered a keynote speech at the conference.,
# POS tag: PERSON,
# Answer: Barack Obama
#
# Sentence: Tesla invested over 2 billion dollars in a new gigafactory in Germany.,
# POS tag: MONEY,
# Answer: 2 billion dollars
#
# Sentence: The concert will take place at 8 p.m. on Saturday.,
# POS tag: TIME,
# Answer: 8 p.m. on Saturday
#
# Sentence: The Eiffel Tower is located in Paris.,
# POS tag: LOCATION,
# Answer: Paris
#
# Sentence: The Olympic Games in Tokyo attracted thousands of visitors despite the pandemic.,
# POS tag: EVENT,
# Answer: Olympic Games
#
# Sentence: The recipe calls for 200 grams of sugar and 3 eggs.,
# POS tag: NUMERICAL,
# Answer: 200 grams
#
# Sentence: Google has opened a new research center in Zurich to focus on AI development.,
# POS tag: ORGANIZATION,
# Answer: Google
#
# Sentence: The American have a long history of culinary excellence.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: American
#
# Sentence: The Islam religion has over a billion followers worldwide.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: Islam
#
# Sentence: Hardest hit by Hugo in South Carolina were small retailers tied to the tourist industry and businesses in agriculture and cultivated seafood.
# POS tag: EVENT
# Answer:
# Gold answer: Hugo
# Gold first token: 'Hugo'
# Pred first token: 'South'
# Top-5: ['South', 'Small', 'Hard', '', 'small']
# 11
# ————————————————————————————————————————————————
# Prompt:  Sentence: Apple announced a new iPhone during its annual product launch event.,
# POS tag: PRODUCT,
# Answer: iPhone
#
# Sentence: Barack Obama delivered a keynote speech at the conference.,
# POS tag: PERSON,
# Answer: Barack Obama
#
# Sentence: Tesla invested over 2 billion dollars in a new gigafactory in Germany.,
# POS tag: MONEY,
# Answer: 2 billion dollars
#
# Sentence: The concert will take place at 8 p.m. on Saturday.,
# POS tag: TIME,
# Answer: 8 p.m. on Saturday
#
# Sentence: The Eiffel Tower is located in Paris.,
# POS tag: LOCATION,
# Answer: Paris
#
# Sentence: The Olympic Games in Tokyo attracted thousands of visitors despite the pandemic.,
# POS tag: EVENT,
# Answer: Olympic Games
#
# Sentence: The recipe calls for 200 grams of sugar and 3 eggs.,
# POS tag: NUMERICAL,
# Answer: 200 grams
#
# Sentence: Google has opened a new research center in Zurich to focus on AI development.,
# POS tag: ORGANIZATION,
# Answer: Google
#
# Sentence: The American have a long history of culinary excellence.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: American
#
# Sentence: The Islam religion has over a billion followers worldwide.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: Islam
#
# Sentence: Pele led Brazil to three World Cup titles and scored more than 1200 goals.
# POS tag: EVENT
# Answer:
# Gold answer: World Cup
# Gold first token: 'World'
# Pred first token: 'World'
# Top-5: ['World', 'Pele', '', 'Brazil', 'Three']
# 12
# ————————————————————————————————————————————————
# Prompt:  Sentence: Apple announced a new iPhone during its annual product launch event.,
# POS tag: PRODUCT,
# Answer: iPhone
#
# Sentence: Barack Obama delivered a keynote speech at the conference.,
# POS tag: PERSON,
# Answer: Barack Obama
#
# Sentence: Tesla invested over 2 billion dollars in a new gigafactory in Germany.,
# POS tag: MONEY,
# Answer: 2 billion dollars
#
# Sentence: The concert will take place at 8 p.m. on Saturday.,
# POS tag: TIME,
# Answer: 8 p.m. on Saturday
#
# Sentence: The Eiffel Tower is located in Paris.,
# POS tag: LOCATION,
# Answer: Paris
#
# Sentence: The Olympic Games in Tokyo attracted thousands of visitors despite the pandemic.,
# POS tag: EVENT,
# Answer: Olympic Games
#
# Sentence: The recipe calls for 200 grams of sugar and 3 eggs.,
# POS tag: NUMERICAL,
# Answer: 200 grams
#
# Sentence: Google has opened a new research center in Zurich to focus on AI development.,
# POS tag: ORGANIZATION,
# Answer: Google
#
# Sentence: The American have a long history of culinary excellence.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: American
#
# Sentence: The Islam religion has over a billion followers worldwide.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: Islam
#
# Sentence: Never before -- not even in the post-World War II heyday of the powerful China Lobby with its formidable grip on Capitol Hill but not within the upper reaches of the Executive itself -- had so many of such uncritical adherence to the policies of a foreign power been so well placed in Washington.
# POS tag: EVENT
# Answer:
# Gold answer: post-World War II
# Gold first token: 'post'
# Pred first token: 'Never'
# Top-5: ['Never', 'China', '', 'never', 'Washington']
# 13
# ————————————————————————————————————————————————
# Prompt:  Sentence: Apple announced a new iPhone during its annual product launch event.,
# POS tag: PRODUCT,
# Answer: iPhone
#
# Sentence: Barack Obama delivered a keynote speech at the conference.,
# POS tag: PERSON,
# Answer: Barack Obama
#
# Sentence: Tesla invested over 2 billion dollars in a new gigafactory in Germany.,
# POS tag: MONEY,
# Answer: 2 billion dollars
#
# Sentence: The concert will take place at 8 p.m. on Saturday.,
# POS tag: TIME,
# Answer: 8 p.m. on Saturday
#
# Sentence: The Eiffel Tower is located in Paris.,
# POS tag: LOCATION,
# Answer: Paris
#
# Sentence: The Olympic Games in Tokyo attracted thousands of visitors despite the pandemic.,
# POS tag: EVENT,
# Answer: Olympic Games
#
# Sentence: The recipe calls for 200 grams of sugar and 3 eggs.,
# POS tag: NUMERICAL,
# Answer: 200 grams
#
# Sentence: Google has opened a new research center in Zurich to focus on AI development.,
# POS tag: ORGANIZATION,
# Answer: Google
#
# Sentence: The American have a long history of culinary excellence.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: American
#
# Sentence: The Islam religion has over a billion followers worldwide.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: Islam
#
# Sentence: According to today's statistics, 2076 people from 42 countries and regions have formally registered for this Sports Meet, among them 1423 are athletes; 1360 news reporters have registered to cover the Sports Meet, among which, 98 are overseas reporters.
# POS tag: EVENT
# Answer:
# Gold answer: the Sports Meet
# Gold first token: 'the'
# Pred first token: ''
# Top-5: ['', 'Sports', 'According', 'The', 'Statistics']
# 14
# ————————————————————————————————————————————————
# Prompt:  Sentence: Apple announced a new iPhone during its annual product launch event.,
# POS tag: PRODUCT,
# Answer: iPhone
#
# Sentence: Barack Obama delivered a keynote speech at the conference.,
# POS tag: PERSON,
# Answer: Barack Obama
#
# Sentence: Tesla invested over 2 billion dollars in a new gigafactory in Germany.,
# POS tag: MONEY,
# Answer: 2 billion dollars
#
# Sentence: The concert will take place at 8 p.m. on Saturday.,
# POS tag: TIME,
# Answer: 8 p.m. on Saturday
#
# Sentence: The Eiffel Tower is located in Paris.,
# POS tag: LOCATION,
# Answer: Paris
#
# Sentence: The Olympic Games in Tokyo attracted thousands of visitors despite the pandemic.,
# POS tag: EVENT,
# Answer: Olympic Games
#
# Sentence: The recipe calls for 200 grams of sugar and 3 eggs.,
# POS tag: NUMERICAL,
# Answer: 200 grams
#
# Sentence: Google has opened a new research center in Zurich to focus on AI development.,
# POS tag: ORGANIZATION,
# Answer: Google
#
# Sentence: The American have a long history of culinary excellence.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: American
#
# Sentence: The Islam religion has over a billion followers worldwide.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: Islam
#
# Sentence: The third step will be to go to the US to take part in the big four world match.
# POS tag: EVENT
# Answer:
# Gold answer: the big four world match
# Gold first token: 'the'
# Pred first token: 'US'
# Top-5: ['US', 'The', '', 'the', 'third']
# 15
# ————————————————————————————————————————————————
# Prompt:  Sentence: Apple announced a new iPhone during its annual product launch event.,
# POS tag: PRODUCT,
# Answer: iPhone
#
# Sentence: Barack Obama delivered a keynote speech at the conference.,
# POS tag: PERSON,
# Answer: Barack Obama
#
# Sentence: Tesla invested over 2 billion dollars in a new gigafactory in Germany.,
# POS tag: MONEY,
# Answer: 2 billion dollars
#
# Sentence: The concert will take place at 8 p.m. on Saturday.,
# POS tag: TIME,
# Answer: 8 p.m. on Saturday
#
# Sentence: The Eiffel Tower is located in Paris.,
# POS tag: LOCATION,
# Answer: Paris
#
# Sentence: The Olympic Games in Tokyo attracted thousands of visitors despite the pandemic.,
# POS tag: EVENT,
# Answer: Olympic Games
#
# Sentence: The recipe calls for 200 grams of sugar and 3 eggs.,
# POS tag: NUMERICAL,
# Answer: 200 grams
#
# Sentence: Google has opened a new research center in Zurich to focus on AI development.,
# POS tag: ORGANIZATION,
# Answer: Google
#
# Sentence: The American have a long history of culinary excellence.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: American
#
# Sentence: The Islam religion has over a billion followers worldwide.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: Islam
#
# Sentence: The space shuttle Atlantis landed at a desert air strip at Edwards Air Force Base, Calif., ending a five - day mission that dispatched the Jupiter - bound Galileo space probe.
# POS tag: LOCATION
# Answer:
# Gold answer: Edwards Air Force Base
# Gold first token: 'Edwards'
# Pred first token: 'Edwards'
# Top-5: ['Edwards', 'California', 'Space', '', 'space']
# 16
# 0
# ————————————————————————————————————————————————
# Prompt:  Sentence: Apple announced a new iPhone during its annual product launch event.,
# POS tag: PRODUCT,
# Answer: iPhone
#
# Sentence: Barack Obama delivered a keynote speech at the conference.,
# POS tag: PERSON,
# Answer: Barack Obama
#
# Sentence: Tesla invested over 2 billion dollars in a new gigafactory in Germany.,
# POS tag: MONEY,
# Answer: 2 billion dollars
#
# Sentence: The concert will take place at 8 p.m. on Saturday.,
# POS tag: TIME,
# Answer: 8 p.m. on Saturday
#
# Sentence: The Eiffel Tower is located in Paris.,
# POS tag: LOCATION,
# Answer: Paris
#
# Sentence: The Olympic Games in Tokyo attracted thousands of visitors despite the pandemic.,
# POS tag: EVENT,
# Answer: Olympic Games
#
# Sentence: The recipe calls for 200 grams of sugar and 3 eggs.,
# POS tag: NUMERICAL,
# Answer: 200 grams
#
# Sentence: Google has opened a new research center in Zurich to focus on AI development.,
# POS tag: ORGANIZATION,
# Answer: Google
#
# Sentence: The American have a long history of culinary excellence.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: American
#
# Sentence: The Islam religion has over a billion followers worldwide.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: Islam
#
# Sentence: The House approved a short - term spending bill to keep the government operating through Nov. 15 and provide $2.85 billion in emergency funds to assist in the recovery from Hurricane Hugo and the California earthquake.
# POS tag: LOCATION
# Answer:
# Gold answer: California
# Gold first token: 'California'
# Pred first token: 'House'
# Top-5: ['House', 'The', 'California', '', 'United']
# 1
# ————————————————————————————————————————————————
# Prompt:  Sentence: Apple announced a new iPhone during its annual product launch event.,
# POS tag: PRODUCT,
# Answer: iPhone
#
# Sentence: Barack Obama delivered a keynote speech at the conference.,
# POS tag: PERSON,
# Answer: Barack Obama
#
# Sentence: Tesla invested over 2 billion dollars in a new gigafactory in Germany.,
# POS tag: MONEY,
# Answer: 2 billion dollars
#
# Sentence: The concert will take place at 8 p.m. on Saturday.,
# POS tag: TIME,
# Answer: 8 p.m. on Saturday
#
# Sentence: The Eiffel Tower is located in Paris.,
# POS tag: LOCATION,
# Answer: Paris
#
# Sentence: The Olympic Games in Tokyo attracted thousands of visitors despite the pandemic.,
# POS tag: EVENT,
# Answer: Olympic Games
#
# Sentence: The recipe calls for 200 grams of sugar and 3 eggs.,
# POS tag: NUMERICAL,
# Answer: 200 grams
#
# Sentence: Google has opened a new research center in Zurich to focus on AI development.,
# POS tag: ORGANIZATION,
# Answer: Google
#
# Sentence: The American have a long history of culinary excellence.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: American
#
# Sentence: The Islam religion has over a billion followers worldwide.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: Islam
#
# Sentence: And Christopher Frank writes from New York about a West Virginia teacher Toni Woods who was sentenced to four to twenty for having sex with four boys under the age of sixteen.
# POS tag: LOCATION
# Answer:
# Gold answer: West Virginia
# Gold first token: 'West'
# Pred first token: 'New'
# Top-5: ['New', 'West', 'And', '', 'Christopher']
# 2
# ————————————————————————————————————————————————
# Prompt:  Sentence: Apple announced a new iPhone during its annual product launch event.,
# POS tag: PRODUCT,
# Answer: iPhone
#
# Sentence: Barack Obama delivered a keynote speech at the conference.,
# POS tag: PERSON,
# Answer: Barack Obama
#
# Sentence: Tesla invested over 2 billion dollars in a new gigafactory in Germany.,
# POS tag: MONEY,
# Answer: 2 billion dollars
#
# Sentence: The concert will take place at 8 p.m. on Saturday.,
# POS tag: TIME,
# Answer: 8 p.m. on Saturday
#
# Sentence: The Eiffel Tower is located in Paris.,
# POS tag: LOCATION,
# Answer: Paris
#
# Sentence: The Olympic Games in Tokyo attracted thousands of visitors despite the pandemic.,
# POS tag: EVENT,
# Answer: Olympic Games
#
# Sentence: The recipe calls for 200 grams of sugar and 3 eggs.,
# POS tag: NUMERICAL,
# Answer: 200 grams
#
# Sentence: Google has opened a new research center in Zurich to focus on AI development.,
# POS tag: ORGANIZATION,
# Answer: Google
#
# Sentence: The American have a long history of culinary excellence.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: American
#
# Sentence: The Islam religion has over a billion followers worldwide.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: Islam
#
# Sentence: There are promotional prices for Dhi Qar Province, ah, to improve the status of contruction in the province.
# POS tag: LOCATION
# Answer:
# Gold answer: Dhi Qar Province
# Gold first token: 'D'
# Pred first token: 'D'
# Top-5: ['D', 'to', 'Ah', '', 'To']
# 3
# ————————————————————————————————————————————————
# Prompt:  Sentence: Apple announced a new iPhone during its annual product launch event.,
# POS tag: PRODUCT,
# Answer: iPhone
#
# Sentence: Barack Obama delivered a keynote speech at the conference.,
# POS tag: PERSON,
# Answer: Barack Obama
#
# Sentence: Tesla invested over 2 billion dollars in a new gigafactory in Germany.,
# POS tag: MONEY,
# Answer: 2 billion dollars
#
# Sentence: The concert will take place at 8 p.m. on Saturday.,
# POS tag: TIME,
# Answer: 8 p.m. on Saturday
#
# Sentence: The Eiffel Tower is located in Paris.,
# POS tag: LOCATION,
# Answer: Paris
#
# Sentence: The Olympic Games in Tokyo attracted thousands of visitors despite the pandemic.,
# POS tag: EVENT,
# Answer: Olympic Games
#
# Sentence: The recipe calls for 200 grams of sugar and 3 eggs.,
# POS tag: NUMERICAL,
# Answer: 200 grams
#
# Sentence: Google has opened a new research center in Zurich to focus on AI development.,
# POS tag: ORGANIZATION,
# Answer: Google
#
# Sentence: The American have a long history of culinary excellence.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: American
#
# Sentence: The Islam religion has over a billion followers worldwide.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: Islam
#
# Sentence: But what's interesting is this guy Paul Hackett who was on this show last week used the most amazing language in describing the President of the United States.
# POS tag: LOCATION
# Answer:
# Gold answer: the United States
# Gold first token: 'the'
# Pred first token: 'Paul'
# Top-5: ['Paul', 'This', '', 'The', 'Washington']
# 4
# ————————————————————————————————————————————————
# Prompt:  Sentence: Apple announced a new iPhone during its annual product launch event.,
# POS tag: PRODUCT,
# Answer: iPhone
#
# Sentence: Barack Obama delivered a keynote speech at the conference.,
# POS tag: PERSON,
# Answer: Barack Obama
#
# Sentence: Tesla invested over 2 billion dollars in a new gigafactory in Germany.,
# POS tag: MONEY,
# Answer: 2 billion dollars
#
# Sentence: The concert will take place at 8 p.m. on Saturday.,
# POS tag: TIME,
# Answer: 8 p.m. on Saturday
#
# Sentence: The Eiffel Tower is located in Paris.,
# POS tag: LOCATION,
# Answer: Paris
#
# Sentence: The Olympic Games in Tokyo attracted thousands of visitors despite the pandemic.,
# POS tag: EVENT,
# Answer: Olympic Games
#
# Sentence: The recipe calls for 200 grams of sugar and 3 eggs.,
# POS tag: NUMERICAL,
# Answer: 200 grams
#
# Sentence: Google has opened a new research center in Zurich to focus on AI development.,
# POS tag: ORGANIZATION,
# Answer: Google
#
# Sentence: The American have a long history of culinary excellence.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: American
#
# Sentence: The Islam religion has over a billion followers worldwide.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: Islam
#
# Sentence: At the same time Palestinians are saying they will not sign a peace deal with Israel that fails to give them sovereignty over all of Arab East Jerusalem or allow the return of refugees.
# POS tag: LOCATION
# Answer:
# Gold answer: Israel
# Gold first token: 'Israel'
# Pred first token: 'Arab'
# Top-5: ['Arab', 'Palestine', 'Palestinian', 'Jerusalem', 'At']
# 5
# ————————————————————————————————————————————————
# Prompt:  Sentence: Apple announced a new iPhone during its annual product launch event.,
# POS tag: PRODUCT,
# Answer: iPhone
#
# Sentence: Barack Obama delivered a keynote speech at the conference.,
# POS tag: PERSON,
# Answer: Barack Obama
#
# Sentence: Tesla invested over 2 billion dollars in a new gigafactory in Germany.,
# POS tag: MONEY,
# Answer: 2 billion dollars
#
# Sentence: The concert will take place at 8 p.m. on Saturday.,
# POS tag: TIME,
# Answer: 8 p.m. on Saturday
#
# Sentence: The Eiffel Tower is located in Paris.,
# POS tag: LOCATION,
# Answer: Paris
#
# Sentence: The Olympic Games in Tokyo attracted thousands of visitors despite the pandemic.,
# POS tag: EVENT,
# Answer: Olympic Games
#
# Sentence: The recipe calls for 200 grams of sugar and 3 eggs.,
# POS tag: NUMERICAL,
# Answer: 200 grams
#
# Sentence: Google has opened a new research center in Zurich to focus on AI development.,
# POS tag: ORGANIZATION,
# Answer: Google
#
# Sentence: The American have a long history of culinary excellence.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: American
#
# Sentence: The Islam religion has over a billion followers worldwide.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: Islam
#
# Sentence: After the policy was formally announced for the Pudong Lujiazui Financial Trade District to allow foreign capital banks to operate RMB business, more than 40 foreign capital banks and financial institutions have submitted applications to establish branches in Pudong.
# POS tag: LOCATION
# Answer:
# Gold answer: Lujiazui Financial Trade District
# Gold first token: 'Lu'
# Pred first token: 'Pud'
# Top-5: ['Pud', '', 'Foreign', 'P', 'more']
# 6
# ————————————————————————————————————————————————
# Prompt:  Sentence: Apple announced a new iPhone during its annual product launch event.,
# POS tag: PRODUCT,
# Answer: iPhone
#
# Sentence: Barack Obama delivered a keynote speech at the conference.,
# POS tag: PERSON,
# Answer: Barack Obama
#
# Sentence: Tesla invested over 2 billion dollars in a new gigafactory in Germany.,
# POS tag: MONEY,
# Answer: 2 billion dollars
#
# Sentence: The concert will take place at 8 p.m. on Saturday.,
# POS tag: TIME,
# Answer: 8 p.m. on Saturday
#
# Sentence: The Eiffel Tower is located in Paris.,
# POS tag: LOCATION,
# Answer: Paris
#
# Sentence: The Olympic Games in Tokyo attracted thousands of visitors despite the pandemic.,
# POS tag: EVENT,
# Answer: Olympic Games
#
# Sentence: The recipe calls for 200 grams of sugar and 3 eggs.,
# POS tag: NUMERICAL,
# Answer: 200 grams
#
# Sentence: Google has opened a new research center in Zurich to focus on AI development.,
# POS tag: ORGANIZATION,
# Answer: Google
#
# Sentence: The American have a long history of culinary excellence.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: American
#
# Sentence: The Islam religion has over a billion followers worldwide.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: Islam
#
# Sentence: He is president and chief executive officer of Comerica Inc. in Detroit.
# POS tag: LOCATION
# Answer:
# Gold answer: Detroit
# Gold first token: 'Detroit'
# Pred first token: 'Comer'
# Top-5: ['Comer', 'Detroit', '', 'He', 'President']
# 7
# ————————————————————————————————————————————————
# Prompt:  Sentence: Apple announced a new iPhone during its annual product launch event.,
# POS tag: PRODUCT,
# Answer: iPhone
#
# Sentence: Barack Obama delivered a keynote speech at the conference.,
# POS tag: PERSON,
# Answer: Barack Obama
#
# Sentence: Tesla invested over 2 billion dollars in a new gigafactory in Germany.,
# POS tag: MONEY,
# Answer: 2 billion dollars
#
# Sentence: The concert will take place at 8 p.m. on Saturday.,
# POS tag: TIME,
# Answer: 8 p.m. on Saturday
#
# Sentence: The Eiffel Tower is located in Paris.,
# POS tag: LOCATION,
# Answer: Paris
#
# Sentence: The Olympic Games in Tokyo attracted thousands of visitors despite the pandemic.,
# POS tag: EVENT,
# Answer: Olympic Games
#
# Sentence: The recipe calls for 200 grams of sugar and 3 eggs.,
# POS tag: NUMERICAL,
# Answer: 200 grams
#
# Sentence: Google has opened a new research center in Zurich to focus on AI development.,
# POS tag: ORGANIZATION,
# Answer: Google
#
# Sentence: The American have a long history of culinary excellence.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: American
#
# Sentence: The Islam religion has over a billion followers worldwide.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: Islam
#
# Sentence: Britain's industrial production rose 1.5% in August from July and was up 0.9% from August 1988, according to provisional data from the Central Statistical Office.
# POS tag: LOCATION
# Answer:
# Gold answer: Britain
# Gold first token: 'Britain'
# Pred first token: 'Britain'
# Top-5: ['Britain', '', 'provisional', 'August', 'Provisional']
# 8
# ————————————————————————————————————————————————
# Prompt:  Sentence: Apple announced a new iPhone during its annual product launch event.,
# POS tag: PRODUCT,
# Answer: iPhone
#
# Sentence: Barack Obama delivered a keynote speech at the conference.,
# POS tag: PERSON,
# Answer: Barack Obama
#
# Sentence: Tesla invested over 2 billion dollars in a new gigafactory in Germany.,
# POS tag: MONEY,
# Answer: 2 billion dollars
#
# Sentence: The concert will take place at 8 p.m. on Saturday.,
# POS tag: TIME,
# Answer: 8 p.m. on Saturday
#
# Sentence: The Eiffel Tower is located in Paris.,
# POS tag: LOCATION,
# Answer: Paris
#
# Sentence: The Olympic Games in Tokyo attracted thousands of visitors despite the pandemic.,
# POS tag: EVENT,
# Answer: Olympic Games
#
# Sentence: The recipe calls for 200 grams of sugar and 3 eggs.,
# POS tag: NUMERICAL,
# Answer: 200 grams
#
# Sentence: Google has opened a new research center in Zurich to focus on AI development.,
# POS tag: ORGANIZATION,
# Answer: Google
#
# Sentence: The American have a long history of culinary excellence.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: American
#
# Sentence: The Islam religion has over a billion followers worldwide.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: Islam
#
# Sentence: The Pentagon tonight says the analyst reports could not have pinpointed the Cole attack, but there's a growing consensus on Capitol Hill that officials here should have seen this disaster coming.
# POS tag: LOCATION
# Answer:
# Gold answer: Capitol Hill
# Gold first token: 'Capitol'
# Pred first token: 'Pentagon'
# Top-5: ['Pentagon', 'The', 'Capitol', 'the', '']
# 9
# ————————————————————————————————————————————————
# Prompt:  Sentence: Apple announced a new iPhone during its annual product launch event.,
# POS tag: PRODUCT,
# Answer: iPhone
#
# Sentence: Barack Obama delivered a keynote speech at the conference.,
# POS tag: PERSON,
# Answer: Barack Obama
#
# Sentence: Tesla invested over 2 billion dollars in a new gigafactory in Germany.,
# POS tag: MONEY,
# Answer: 2 billion dollars
#
# Sentence: The concert will take place at 8 p.m. on Saturday.,
# POS tag: TIME,
# Answer: 8 p.m. on Saturday
#
# Sentence: The Eiffel Tower is located in Paris.,
# POS tag: LOCATION,
# Answer: Paris
#
# Sentence: The Olympic Games in Tokyo attracted thousands of visitors despite the pandemic.,
# POS tag: EVENT,
# Answer: Olympic Games
#
# Sentence: The recipe calls for 200 grams of sugar and 3 eggs.,
# POS tag: NUMERICAL,
# Answer: 200 grams
#
# Sentence: Google has opened a new research center in Zurich to focus on AI development.,
# POS tag: ORGANIZATION,
# Answer: Google
#
# Sentence: The American have a long history of culinary excellence.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: American
#
# Sentence: The Islam religion has over a billion followers worldwide.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: Islam
#
# Sentence: Xinhua News Agency, Beijing, January 14th, by reporter Yongjian Lu
# POS tag: LOCATION
# Answer:
# Gold answer: Beijing
# Gold first token: 'Beijing'
# Pred first token: 'Beijing'
# Top-5: ['Beijing', 'Xinhua', '', 'China', 'by']
# 10
# ————————————————————————————————————————————————
# Prompt:  Sentence: Apple announced a new iPhone during its annual product launch event.,
# POS tag: PRODUCT,
# Answer: iPhone
#
# Sentence: Barack Obama delivered a keynote speech at the conference.,
# POS tag: PERSON,
# Answer: Barack Obama
#
# Sentence: Tesla invested over 2 billion dollars in a new gigafactory in Germany.,
# POS tag: MONEY,
# Answer: 2 billion dollars
#
# Sentence: The concert will take place at 8 p.m. on Saturday.,
# POS tag: TIME,
# Answer: 8 p.m. on Saturday
#
# Sentence: The Eiffel Tower is located in Paris.,
# POS tag: LOCATION,
# Answer: Paris
#
# Sentence: The Olympic Games in Tokyo attracted thousands of visitors despite the pandemic.,
# POS tag: EVENT,
# Answer: Olympic Games
#
# Sentence: The recipe calls for 200 grams of sugar and 3 eggs.,
# POS tag: NUMERICAL,
# Answer: 200 grams
#
# Sentence: Google has opened a new research center in Zurich to focus on AI development.,
# POS tag: ORGANIZATION,
# Answer: Google
#
# Sentence: The American have a long history of culinary excellence.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: American
#
# Sentence: The Islam religion has over a billion followers worldwide.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: Islam
#
# Sentence: But at age 55, they may be a great deal, says Mr. Wilson, the Columbia, S.C., planner.
# POS tag: LOCATION
# Answer:
# Gold answer: S.C.
# Gold first token: 'S'
# Pred first token: 'Columbia'
# Top-5: ['Columbia', '', 'Mr', 'age', 'S']
# 11
# ————————————————————————————————————————————————
# Prompt:  Sentence: Apple announced a new iPhone during its annual product launch event.,
# POS tag: PRODUCT,
# Answer: iPhone
#
# Sentence: Barack Obama delivered a keynote speech at the conference.,
# POS tag: PERSON,
# Answer: Barack Obama
#
# Sentence: Tesla invested over 2 billion dollars in a new gigafactory in Germany.,
# POS tag: MONEY,
# Answer: 2 billion dollars
#
# Sentence: The concert will take place at 8 p.m. on Saturday.,
# POS tag: TIME,
# Answer: 8 p.m. on Saturday
#
# Sentence: The Eiffel Tower is located in Paris.,
# POS tag: LOCATION,
# Answer: Paris
#
# Sentence: The Olympic Games in Tokyo attracted thousands of visitors despite the pandemic.,
# POS tag: EVENT,
# Answer: Olympic Games
#
# Sentence: The recipe calls for 200 grams of sugar and 3 eggs.,
# POS tag: NUMERICAL,
# Answer: 200 grams
#
# Sentence: Google has opened a new research center in Zurich to focus on AI development.,
# POS tag: ORGANIZATION,
# Answer: Google
#
# Sentence: The American have a long history of culinary excellence.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: American
#
# Sentence: The Islam religion has over a billion followers worldwide.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: Islam
#
# Sentence: The Reagan administration also put Mr. Noriega's G - 2 back on the U.S. payroll.
# POS tag: LOCATION
# Answer:
# Gold answer: U.S.
# Gold first token: 'U'
# Pred first token: 'U'
# Top-5: ['U', 'G', 'Reagan', 'The', 'United']
# 12
# ————————————————————————————————————————————————
# Prompt:  Sentence: Apple announced a new iPhone during its annual product launch event.,
# POS tag: PRODUCT,
# Answer: iPhone
#
# Sentence: Barack Obama delivered a keynote speech at the conference.,
# POS tag: PERSON,
# Answer: Barack Obama
#
# Sentence: Tesla invested over 2 billion dollars in a new gigafactory in Germany.,
# POS tag: MONEY,
# Answer: 2 billion dollars
#
# Sentence: The concert will take place at 8 p.m. on Saturday.,
# POS tag: TIME,
# Answer: 8 p.m. on Saturday
#
# Sentence: The Eiffel Tower is located in Paris.,
# POS tag: LOCATION,
# Answer: Paris
#
# Sentence: The Olympic Games in Tokyo attracted thousands of visitors despite the pandemic.,
# POS tag: EVENT,
# Answer: Olympic Games
#
# Sentence: The recipe calls for 200 grams of sugar and 3 eggs.,
# POS tag: NUMERICAL,
# Answer: 200 grams
#
# Sentence: Google has opened a new research center in Zurich to focus on AI development.,
# POS tag: ORGANIZATION,
# Answer: Google
#
# Sentence: The American have a long history of culinary excellence.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: American
#
# Sentence: The Islam religion has over a billion followers worldwide.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: Islam
#
# Sentence: Telxon Corp. said its vice president for manufacturing resigned and its Houston work force has been trimmed by 40 people, or about 15%.
# POS tag: LOCATION
# Answer:
# Gold answer: Houston
# Gold first token: 'Houston'
# Pred first token: 'Houston'
# Top-5: ['Houston', '', 'Tel', 'Texas', '']
# 13
# ————————————————————————————————————————————————
# Prompt:  Sentence: Apple announced a new iPhone during its annual product launch event.,
# POS tag: PRODUCT,
# Answer: iPhone
#
# Sentence: Barack Obama delivered a keynote speech at the conference.,
# POS tag: PERSON,
# Answer: Barack Obama
#
# Sentence: Tesla invested over 2 billion dollars in a new gigafactory in Germany.,
# POS tag: MONEY,
# Answer: 2 billion dollars
#
# Sentence: The concert will take place at 8 p.m. on Saturday.,
# POS tag: TIME,
# Answer: 8 p.m. on Saturday
#
# Sentence: The Eiffel Tower is located in Paris.,
# POS tag: LOCATION,
# Answer: Paris
#
# Sentence: The Olympic Games in Tokyo attracted thousands of visitors despite the pandemic.,
# POS tag: EVENT,
# Answer: Olympic Games
#
# Sentence: The recipe calls for 200 grams of sugar and 3 eggs.,
# POS tag: NUMERICAL,
# Answer: 200 grams
#
# Sentence: Google has opened a new research center in Zurich to focus on AI development.,
# POS tag: ORGANIZATION,
# Answer: Google
#
# Sentence: The American have a long history of culinary excellence.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: American
#
# Sentence: The Islam religion has over a billion followers worldwide.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: Islam
#
# Sentence: Rising inflation in Poland and Hungary makes Czechoslovak food, clothing and shoes relatively cheap for visitors from these countries.
# POS tag: LOCATION
# Answer:
# Gold answer: Hungary
# Gold first token: 'Hungary'
# Pred first token: 'Poland'
# Top-5: ['Poland', 'Rising', '', 'Czech', 'Polish']
# 14
# ————————————————————————————————————————————————
# Prompt:  Sentence: Apple announced a new iPhone during its annual product launch event.,
# POS tag: PRODUCT,
# Answer: iPhone
#
# Sentence: Barack Obama delivered a keynote speech at the conference.,
# POS tag: PERSON,
# Answer: Barack Obama
#
# Sentence: Tesla invested over 2 billion dollars in a new gigafactory in Germany.,
# POS tag: MONEY,
# Answer: 2 billion dollars
#
# Sentence: The concert will take place at 8 p.m. on Saturday.,
# POS tag: TIME,
# Answer: 8 p.m. on Saturday
#
# Sentence: The Eiffel Tower is located in Paris.,
# POS tag: LOCATION,
# Answer: Paris
#
# Sentence: The Olympic Games in Tokyo attracted thousands of visitors despite the pandemic.,
# POS tag: EVENT,
# Answer: Olympic Games
#
# Sentence: The recipe calls for 200 grams of sugar and 3 eggs.,
# POS tag: NUMERICAL,
# Answer: 200 grams
#
# Sentence: Google has opened a new research center in Zurich to focus on AI development.,
# POS tag: ORGANIZATION,
# Answer: Google
#
# Sentence: The American have a long history of culinary excellence.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: American
#
# Sentence: The Islam religion has over a billion followers worldwide.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: Islam
#
# ...
# POS tag: TIME
# Answer:
# Gold answer: 1992
# Gold first token: ''
# Pred first token: ''
# Top-5: ['', 'They', 'in', 'they', 'It']
# 14
# ————————————————————————————————————————————————
# Prompt:  Sentence: Apple announced a new iPhone during its annual product launch event.,
# POS tag: PRODUCT,
# Answer: iPhone
#
# Sentence: Barack Obama delivered a keynote speech at the conference.,
# POS tag: PERSON,
# Answer: Barack Obama
#
# Sentence: Tesla invested over 2 billion dollars in a new gigafactory in Germany.,
# POS tag: MONEY,
# Answer: 2 billion dollars
#
# Sentence: The concert will take place at 8 p.m. on Saturday.,
# POS tag: TIME,
# Answer: 8 p.m. on Saturday
#
# Sentence: The Eiffel Tower is located in Paris.,
# POS tag: LOCATION,
# Answer: Paris
#
# Sentence: The Olympic Games in Tokyo attracted thousands of visitors despite the pandemic.,
# POS tag: EVENT,
# Answer: Olympic Games
#
# Sentence: The recipe calls for 200 grams of sugar and 3 eggs.,
# POS tag: NUMERICAL,
# Answer: 200 grams
#
# Sentence: Google has opened a new research center in Zurich to focus on AI development.,
# POS tag: ORGANIZATION,
# Answer: Google
#
# Sentence: The American have a long history of culinary excellence.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: American
#
# Sentence: The Islam religion has over a billion followers worldwide.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: Islam
#
# Sentence: Last month, American Home Products said it was suspending production and distribution of all 21 of Quantum's generic drug products pending the completion of an exhaustive internal audit.
# POS tag: TIME
# Answer:
# Gold answer: Last month
# Gold first token: 'Last'
# Pred first token: ''
# Top-5: ['', 'last', 'Last', 'Quantum', 'pending']
# 15
# ————————————————————————————————————————————————
# Prompt:  Sentence: Apple announced a new iPhone during its annual product launch event.,
# POS tag: PRODUCT,
# Answer: iPhone
#
# Sentence: Barack Obama delivered a keynote speech at the conference.,
# POS tag: PERSON,
# Answer: Barack Obama
#
# Sentence: Tesla invested over 2 billion dollars in a new gigafactory in Germany.,
# POS tag: MONEY,
# Answer: 2 billion dollars
#
# Sentence: The concert will take place at 8 p.m. on Saturday.,
# POS tag: TIME,
# Answer: 8 p.m. on Saturday
#
# Sentence: The Eiffel Tower is located in Paris.,
# POS tag: LOCATION,
# Answer: Paris
#
# Sentence: The Olympic Games in Tokyo attracted thousands of visitors despite the pandemic.,
# POS tag: EVENT,
# Answer: Olympic Games
#
# Sentence: The recipe calls for 200 grams of sugar and 3 eggs.,
# POS tag: NUMERICAL,
# Answer: 200 grams
#
# Sentence: Google has opened a new research center in Zurich to focus on AI development.,
# POS tag: ORGANIZATION,
# Answer: Google
#
# Sentence: The American have a long history of culinary excellence.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: American
#
# Sentence: The Islam religion has over a billion followers worldwide.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: Islam
#
# Sentence: September's Hang Seng Consumer Price Index, which measures price changes for the 10% of urban households spending HK$10,000 and HK$24,999 a month, was up 11% from a year ago and up 1.3% from August.
# POS tag: TIME
# Answer:
# Gold answer: August
# Gold first token: 'August'
# Pred first token: 'September'
# Top-5: ['September', '', 'Hang', 'August', '']
# 8
# 0
# ————————————————————————————————————————————————
# Prompt:  Sentence: Apple announced a new iPhone during its annual product launch event.,
# POS tag: PRODUCT,
# Answer: iPhone
#
# Sentence: Barack Obama delivered a keynote speech at the conference.,
# POS tag: PERSON,
# Answer: Barack Obama
#
# Sentence: Tesla invested over 2 billion dollars in a new gigafactory in Germany.,
# POS tag: MONEY,
# Answer: 2 billion dollars
#
# Sentence: The concert will take place at 8 p.m. on Saturday.,
# POS tag: TIME,
# Answer: 8 p.m. on Saturday
#
# Sentence: The Eiffel Tower is located in Paris.,
# POS tag: LOCATION,
# Answer: Paris
#
# Sentence: The Olympic Games in Tokyo attracted thousands of visitors despite the pandemic.,
# POS tag: EVENT,
# Answer: Olympic Games
#
# Sentence: The recipe calls for 200 grams of sugar and 3 eggs.,
# POS tag: NUMERICAL,
# Answer: 200 grams
#
# Sentence: Google has opened a new research center in Zurich to focus on AI development.,
# POS tag: ORGANIZATION,
# Answer: Google
#
# Sentence: The American have a long history of culinary excellence.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: American
#
# Sentence: The Islam religion has over a billion followers worldwide.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: Islam
#
# Sentence: The return to work Thursday came at the urging of Catholic NUMERICAL Roger Mahodi who said the labor dispute was hurting the poor who rely on public services.
# POS tag: TIME
# Answer:
# Gold answer: Thursday
# Gold first token: 'Thursday'
# Pred first token: 'Thursday'
# Top-5: ['Thursday', '', 'The', 'Catholic', 'Return']
# 1
# ————————————————————————————————————————————————
# Prompt:  Sentence: Apple announced a new iPhone during its annual product launch event.,
# POS tag: PRODUCT,
# Answer: iPhone
#
# Sentence: Barack Obama delivered a keynote speech at the conference.,
# POS tag: PERSON,
# Answer: Barack Obama
#
# Sentence: Tesla invested over 2 billion dollars in a new gigafactory in Germany.,
# POS tag: MONEY,
# Answer: 2 billion dollars
#
# Sentence: The concert will take place at 8 p.m. on Saturday.,
# POS tag: TIME,
# Answer: 8 p.m. on Saturday
#
# Sentence: The Eiffel Tower is located in Paris.,
# POS tag: LOCATION,
# Answer: Paris
#
# Sentence: The Olympic Games in Tokyo attracted thousands of visitors despite the pandemic.,
# POS tag: EVENT,
# Answer: Olympic Games
#
# Sentence: The recipe calls for 200 grams of sugar and 3 eggs.,
# POS tag: NUMERICAL,
# Answer: 200 grams
#
# Sentence: Google has opened a new research center in Zurich to focus on AI development.,
# POS tag: ORGANIZATION,
# Answer: Google
#
# Sentence: The American have a long history of culinary excellence.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: American
#
# Sentence: The Islam religion has over a billion followers worldwide.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: Islam
#
# Sentence: Arthur Klein, president of Young & Rubicam's New York office, stepped down temporarily in the wake of charges by a federal grand jury in New Haven, Conn., that he, the agency and another top executive bribed Jamaican tourist officials to win its account in 1981.
# POS tag: TIME
# Answer:
# Gold answer: 1981
# Gold first token: ''
# Pred first token: ''
# Top-5: ['', 'Arthur', 'Temporary', 'The', 'in']
# 2
# ————————————————————————————————————————————————
# Prompt:  Sentence: Apple announced a new iPhone during its annual product launch event.,
# POS tag: PRODUCT,
# Answer: iPhone
#
# Sentence: Barack Obama delivered a keynote speech at the conference.,
# POS tag: PERSON,
# Answer: Barack Obama
#
# Sentence: Tesla invested over 2 billion dollars in a new gigafactory in Germany.,
# POS tag: MONEY,
# Answer: 2 billion dollars
#
# Sentence: The concert will take place at 8 p.m. on Saturday.,
# POS tag: TIME,
# Answer: 8 p.m. on Saturday
#
# Sentence: The Eiffel Tower is located in Paris.,
# POS tag: LOCATION,
# Answer: Paris
#
# Sentence: The Olympic Games in Tokyo attracted thousands of visitors despite the pandemic.,
# POS tag: EVENT,
# Answer: Olympic Games
#
# Sentence: The recipe calls for 200 grams of sugar and 3 eggs.,
# POS tag: NUMERICAL,
# Answer: 200 grams
#
# Sentence: Google has opened a new research center in Zurich to focus on AI development.,
# POS tag: ORGANIZATION,
# Answer: Google
#
# Sentence: The American have a long history of culinary excellence.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: American
#
# Sentence: The Islam religion has over a billion followers worldwide.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: Islam
#
# Sentence: To find out why, the group recently commissioned a study of the past 20 years of bowling - related research.
# POS tag: TIME
# Answer:
# Gold answer: the past 20 years
# Gold first token: 'the'
# Pred first token: ''
# Top-5: ['', 'To', 'past', 'The', 'Past']
# 3
# ————————————————————————————————————————————————
# Prompt:  Sentence: Apple announced a new iPhone during its annual product launch event.,
# POS tag: PRODUCT,
# Answer: iPhone
#
# Sentence: Barack Obama delivered a keynote speech at the conference.,
# POS tag: PERSON,
# Answer: Barack Obama
#
# Sentence: Tesla invested over 2 billion dollars in a new gigafactory in Germany.,
# POS tag: MONEY,
# Answer: 2 billion dollars
#
# Sentence: The concert will take place at 8 p.m. on Saturday.,
# POS tag: TIME,
# Answer: 8 p.m. on Saturday
#
# Sentence: The Eiffel Tower is located in Paris.,
# POS tag: LOCATION,
# Answer: Paris
#
# Sentence: The Olympic Games in Tokyo attracted thousands of visitors despite the pandemic.,
# POS tag: EVENT,
# Answer: Olympic Games
#
# Sentence: The recipe calls for 200 grams of sugar and 3 eggs.,
# POS tag: NUMERICAL,
# Answer: 200 grams
#
# Sentence: Google has opened a new research center in Zurich to focus on AI development.,
# POS tag: ORGANIZATION,
# Answer: Google
#
# Sentence: The American have a long history of culinary excellence.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: American
#
# Sentence: The Islam religion has over a billion followers worldwide.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: Islam
#
# Sentence: Well his term ends in January of oh seven.
# POS tag: TIME
# Answer:
# Gold answer: January of oh seven
# Gold first token: 'January'
# Pred first token: 'January'
# Top-5: ['January', '', 'Oh', 'oh', 'Well']
# 4
# ————————————————————————————————————————————————
# Prompt:  Sentence: Apple announced a new iPhone during its annual product launch event.,
# POS tag: PRODUCT,
# Answer: iPhone
#
# Sentence: Barack Obama delivered a keynote speech at the conference.,
# POS tag: PERSON,
# Answer: Barack Obama
#
# Sentence: Tesla invested over 2 billion dollars in a new gigafactory in Germany.,
# POS tag: MONEY,
# Answer: 2 billion dollars
#
# Sentence: The concert will take place at 8 p.m. on Saturday.,
# POS tag: TIME,
# Answer: 8 p.m. on Saturday
#
# Sentence: The Eiffel Tower is located in Paris.,
# POS tag: LOCATION,
# Answer: Paris
#
# Sentence: The Olympic Games in Tokyo attracted thousands of visitors despite the pandemic.,
# POS tag: EVENT,
# Answer: Olympic Games
#
# Sentence: The recipe calls for 200 grams of sugar and 3 eggs.,
# POS tag: NUMERICAL,
# Answer: 200 grams
#
# Sentence: Google has opened a new research center in Zurich to focus on AI development.,
# POS tag: ORGANIZATION,
# Answer: Google
#
# Sentence: The American have a long history of culinary excellence.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: American
#
# Sentence: The Islam religion has over a billion followers worldwide.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: Islam
#
# Sentence: Completion of the sale is expected early next year, Falcon said.
# POS tag: TIME
# Answer:
# Gold answer: early next year
# Gold first token: 'early'
# Pred first token: 'early'
# Top-5: ['early', 'Early', '', 'expected', 'Expected']
# 5
# ————————————————————————————————————————————————
# Prompt:  Sentence: Apple announced a new iPhone during its annual product launch event.,
# POS tag: PRODUCT,
# Answer: iPhone
#
# Sentence: Barack Obama delivered a keynote speech at the conference.,
# POS tag: PERSON,
# Answer: Barack Obama
#
# Sentence: Tesla invested over 2 billion dollars in a new gigafactory in Germany.,
# POS tag: MONEY,
# Answer: 2 billion dollars
#
# Sentence: The concert will take place at 8 p.m. on Saturday.,
# POS tag: TIME,
# Answer: 8 p.m. on Saturday
#
# Sentence: The Eiffel Tower is located in Paris.,
# POS tag: LOCATION,
# Answer: Paris
#
# Sentence: The Olympic Games in Tokyo attracted thousands of visitors despite the pandemic.,
# POS tag: EVENT,
# Answer: Olympic Games
#
# Sentence: The recipe calls for 200 grams of sugar and 3 eggs.,
# POS tag: NUMERICAL,
# Answer: 200 grams
#
# Sentence: Google has opened a new research center in Zurich to focus on AI development.,
# POS tag: ORGANIZATION,
# Answer: Google
#
# Sentence: The American have a long history of culinary excellence.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: American
#
# Sentence: The Islam religion has over a billion followers worldwide.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: Islam
#
# Sentence: Qin Shi Huang united China in the year 221 B.C.
# POS tag: TIME
# Answer:
# Gold answer: the year 221 B.C
# Gold first token: 'the'
# Pred first token: ''
# Top-5: ['', 'B', 'Qin', 'year', 'Year']
# 6
# ————————————————————————————————————————————————
# Prompt:  Sentence: Apple announced a new iPhone during its annual product launch event.,
# POS tag: PRODUCT,
# Answer: iPhone
#
# Sentence: Barack Obama delivered a keynote speech at the conference.,
# POS tag: PERSON,
# Answer: Barack Obama
#
# Sentence: Tesla invested over 2 billion dollars in a new gigafactory in Germany.,
# POS tag: MONEY,
# Answer: 2 billion dollars
#
# Sentence: The concert will take place at 8 p.m. on Saturday.,
# POS tag: TIME,
# Answer: 8 p.m. on Saturday
#
# Sentence: The Eiffel Tower is located in Paris.,
# POS tag: LOCATION,
# Answer: Paris
#
# Sentence: The Olympic Games in Tokyo attracted thousands of visitors despite the pandemic.,
# POS tag: EVENT,
# Answer: Olympic Games
#
# Sentence: The recipe calls for 200 grams of sugar and 3 eggs.,
# POS tag: NUMERICAL,
# Answer: 200 grams
#
# Sentence: Google has opened a new research center in Zurich to focus on AI development.,
# POS tag: ORGANIZATION,
# Answer: Google
#
# Sentence: The American have a long history of culinary excellence.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: American
#
# Sentence: The Islam religion has over a billion followers worldwide.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: Islam
#
# Sentence: According to statistics, up to the end of July this year, Tianjin had approved a total of 871 Taiwanese business invested enterprises.
# POS tag: TIME
# Answer:
# Gold answer: up to the end of July this year
# Gold first token: 'up'
# Pred first token: ''
# Top-5: ['', 'up', 'According', 'Up', 'according']
# 7
# ————————————————————————————————————————————————
# Prompt:  Sentence: Apple announced a new iPhone during its annual product launch event.,
# POS tag: PRODUCT,
# Answer: iPhone
#
# Sentence: Barack Obama delivered a keynote speech at the conference.,
# POS tag: PERSON,
# Answer: Barack Obama
#
# Sentence: Tesla invested over 2 billion dollars in a new gigafactory in Germany.,
# POS tag: MONEY,
# Answer: 2 billion dollars
#
# Sentence: The concert will take place at 8 p.m. on Saturday.,
# POS tag: TIME,
# Answer: 8 p.m. on Saturday
#
# Sentence: The Eiffel Tower is located in Paris.,
# POS tag: LOCATION,
# Answer: Paris
#
# Sentence: The Olympic Games in Tokyo attracted thousands of visitors despite the pandemic.,
# POS tag: EVENT,
# Answer: Olympic Games
#
# Sentence: The recipe calls for 200 grams of sugar and 3 eggs.,
# POS tag: NUMERICAL,
# Answer: 200 grams
#
# Sentence: Google has opened a new research center in Zurich to focus on AI development.,
# POS tag: ORGANIZATION,
# Answer: Google
#
# Sentence: The American have a long history of culinary excellence.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: American
#
# Sentence: The Islam religion has over a billion followers worldwide.,
# POS tag: NATIONALITY, RELIGIOUS, or POLITICAL GROUP,
# Answer: Islam
#
# Sentence: Maryland Stadium Authority -- $137.6 million of sports facilities lease revenue bonds, Series 1989 D, due 1992 - 1999, 2004, 2009 and 2019, tentatively priced at par by a Morgan Stanley group to yield from 6.35% in 1992 to 7.60% in 2019.
# POS tag: TIME
# Answer:
# Gold answer: 2019
# Gold first token: ''
# Pred first token: ''
# Top-5: ['', '$', 'Maryland', '', 'Series']
#
# ✅ Next-token accuracy: 63/120 = 52.50%
# 52.5
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
